# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=60)
lngs = np.random.uniform(low=-180.000, high=180.000, size=60)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 51

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create a dataframe to store all the cities and countries generated with citipy
df_countries = pd.DataFrame({'City': cities})

#add additional blank columns to store information from openweathermap api
df_countries['Latitude'] = ''
df_countries['Longitude'] = ''
df_countries['Max Temperature (F)'] = ''
df_countries['Humidity (%)'] = ''
df_countries['Cloudiness (%)'] = ''
df_countries['Wind Speed (mph)'] = ''
df_countries['Date'] = ''

#base url
weather_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="

#loop through all rows and fill in values for blank columns in dataframe
for index,row in df_countries.iterrows(): 
    # Get json respose for each city
    response = requests.get(weather_url+row['City']).json() 
    
    #adding response data to respective columns
    df_countries.loc[index,'Latitude'] = response.get("coord", {}).get("lat", "unknown")
    df_countries.loc[index,'Longitude'] = response.get("coord", {}).get("lon", "unknown")
    df_countries.loc[index,'Max Temperature (F)'] = response.get("main", {}).get("temp_max", "unknown")
    df_countries.loc[index,'Humidity (%)'] = response.get("main", {}).get("humidity", "unknown")
    df_countries.loc[index,'Cloudiness (%)'] = response.get('clouds', {}).get('all', 'unknown')
    df_countries.loc[index,'Wind Speed (mph)'] = response.get("wind", {}).get("speed", "unknown")
    df_countries.loc[index, 'Date'] = response.get("dt", "unknown")
    
    #print results
    print(f'Processing City: {row[0]}, City Number: {index}')
# Out:
# Processing City: izoplit, City Number: 0
# Processing City: vaini, City Number: 1
# Processing City: kaitangata, City Number: 2
# Processing City: oxbow, City Number: 3
# Processing City: doume, City Number: 4
# Processing City: herat, City Number: 5
# Processing City: ponta do sol, City Number: 6
# Processing City: rabo de peixe, City Number: 7
# Processing City: tsihombe, City Number: 8
# Processing City: hilo, City Number: 9
# Processing City: puerto ayora, City Number: 10
# Processing City: punta arenas, City Number: 11
# Processing City: rikitea, City Number: 12
# Processing City: tarauaca, City Number: 13
# Processing City: bengkulu, City Number: 14
# Processing City: busselton, City Number: 15
# Processing City: rurrenabaque, City Number: 16
# Processing City: narsaq, City Number: 17
# Processing City: hermanus, City Number: 18
# Processing City: butaritari, City Number: 19
# Processing City: vredendal, City Number: 20
# Processing City: bluff, City Number: 21
# Processing City: mys shmidta, City Number: 22
# Processing City: cape town, City Number: 23
# Processing City: priargunsk, City Number: 24
# Processing City: lebu, City Number: 25
# Processing City: east london, City Number: 26
# Processing City: ancud, City Number: 27
# Processing City: mar del plata, City Number: 28
# Processing City: atuona, City Number: 29
# Processing City: olafsvik, City Number: 30
# Processing City: cidreira, City Number: 31
# Processing City: ushuaia, City Number: 32
# Processing City: rio grande, City Number: 33
# Processing City: laguna, City Number: 34
# Processing City: kapaa, City Number: 35
# Processing City: tocopilla, City Number: 36
# Processing City: pitimbu, City Number: 37
# Processing City: talnakh, City Number: 38
# Processing City: nizhneyansk, City Number: 39
# Processing City: nikolskoye, City Number: 40
# Processing City: dikson, City Number: 41
# Processing City: jamestown, City Number: 42
# Processing City: adrar, City Number: 43
# Processing City: maldonado, City Number: 44
# Processing City: kupang, City Number: 45
# Processing City: flinders, City Number: 46
# Processing City: georgetown, City Number: 47
# Processing City: cayenne, City Number: 48
# Processing City: palmares do sul, City Number: 49
# Processing City: khatanga, City Number: 50

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Get names of indexes for which the row values are unknown
index_unknowns = df_countries[ df_countries['Latitude'] == 'unknown' ].index
 
# Delete these row indexes from dataFrame
df_countries.drop(index_unknowns , inplace=True) 

#export cleaned df to csv
df_countries.to_csv(r'C:\Users\Owner\Desktop\Bootcamp_classwork\GT-PTCH-DATA-PT-11-2019-U-C\001-Homework\06-Python-APIs\Instructions\output_data\cities.csv')

# %%
#displayed clean df
df_countries
# Out:
#                City Latitude Longitude Max Temperature (F) Humidity (%)  \
# 0           izoplit    56.63     36.22               30.74           94
# 1             vaini    -21.2    -175.2                  86           79
# 2        kaitangata   -46.28    169.85                  64           67
# 3             oxbow    49.23   -102.17                26.6           92
# 4             doume     4.23     13.45               67.21           31
# 5             herat     34.5        62                  32           41
# 6      ponta do sol    32.67     -17.1                60.8           72
# 7     rabo de peixe     37.8    -25.58                62.6           93
# 9              hilo    19.73   -155.09                80.6           61
# 10     puerto ayora    -0.74    -90.35                84.2           62
# 11     punta arenas   -53.15    -70.92                  50           76
# 12          rikitea   -23.12   -134.97               79.93           75
# 13         tarauaca    -8.16    -70.77               75.94           83
# 14         bengkulu     -3.8    102.27               72.32           75
# 15        busselton   -33.65    115.33               60.01           81
# 16     rurrenabaque   -14.44    -67.53               73.27           98
# 17           narsaq    60.92    -46.05                10.4           60
# 18         hermanus   -34.42     19.23                  64           81
# 19       butaritari     3.07    172.79               84.42           74
# 20        vredendal   -31.67      18.5               65.68           65
# 21            bluff    -46.6    168.33               64.47           47
# 23        cape town   -33.93     18.42                  68           63
# 24       priargunsk    50.37     119.1              -14.03          100
# 25             lebu   -37.62    -73.65               55.74           65
# 26      east london   -33.02     27.91               70.68           79
# 27            ancud   -41.87    -73.82                53.6           66
# 28    mar del plata      -38    -57.56                  61           62
# 29           atuona     -9.8   -139.03               81.27           74
# 30         olafsvik    64.89    -23.71               33.15           83
# 31         cidreira   -30.18    -50.21                75.9           82
# 32          ushuaia    -54.8     -68.3               37.45           98
# 33       rio grande   -32.03     -52.1                  77           79
# 34           laguna    38.42   -121.42               66.99           55
# 35            kapaa    22.08   -159.32                82.4           48
# 36        tocopilla   -22.09     -70.2               60.19           68
# 37          pitimbu    -7.47    -34.81                78.8           78
# 38          talnakh    69.49      88.4                -9.4           83
# 40       nikolskoye     59.7     30.79                30.2           92
# 41           dikson    73.51     80.55              -23.66           98
# 42        jamestown     42.1    -79.24                  25           85
# 43            adrar     20.5    -10.07               69.51           19
# 44        maldonado   -34.67    -54.92                  68           82
# 45           kupang   -10.17    123.58                84.2           83
# 46         flinders   -34.58    150.86                  82           51
# 47       georgetown     5.41    100.34                78.8           94
# 48          cayenne     4.93    -52.33                80.6           78
# 49  palmares do sul   -30.26    -50.51               73.63           76
# 50         khatanga    71.97     102.5              -14.35           98
#
#    Cloudiness (%) Wind Speed (mph)        Date
# 0             100             8.63  1580345428
# 1              75             9.17  1580345429
# 2              75            10.51  1580345429
# 3              90             2.24  1580345151
# 4              86             3.06  1580345429
# 5              70             2.24  1580345429
# 6              20             5.82  1580345429
# 7              40            13.87  1580345431
# 9              75            10.29  1580345431
# 10             75            10.29  1580345434
# 11            100            15.01  1580345299
# 12            100             9.91  1580345436
# 13             68             1.23  1580345148
# 14            100             3.98  1580345437
# 15             34             5.99  1580345437
# 16             95             1.79  1580345437
# 17              7             5.82  1580345437
# 18              0             5.01  1580345437
# 19             92             8.23  1580345437
# 20              0             3.53  1580345437
# 21             90            10.89  1580345439
# 23             20            24.16  1580345168
# 24            100             2.93  1580345439
# 25             18             8.88  1580345440
# 26            100             7.58  1580345440
# 27             40             8.05  1580345440
# 28             89             6.93  1580345215
# 29              1            15.79  1580345440
# 30             64            16.96  1580345440
# 31             60             17.6  1580345441
# 32            100             9.01  1580345155
# 33             49            10.56  1580345442
# 34              1             9.17  1580345443
# 35              1            10.29  1580345443
# 36              0             3.18  1580345444
# 37             20             6.93  1580345444
# 38             75             2.24  1580345444
# 40             90            13.42  1580345445
# 41             86             4.61  1580345445
# 42              1             5.82  1580345445
# 43             95            12.21  1580345445
# 44             90            17.22  1580345447
# 45             40            10.29  1580345292
# 46              0             5.82  1580345448
# 47             20             1.68  1580345353
# 48             40             8.05  1580345448
# 49             51             7.83  1580345449
# 50             98             3.65  1580345449

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_countries["Latitude"], df_countries["Max Temperature (F)"], color='b')
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs Max Temperature')
plt.savefig("../output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_countries["Latitude"], df_countries["Humidity (%)"], color='b')
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs Humidity')
plt.savefig("../output_data/Fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_countries["Latitude"], df_countries["Cloudiness (%)"], color='b')
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs Cloudiness')
plt.savefig("../output_data/Fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_countries["Latitude"], df_countries["Wind Speed (mph)"], color='b')
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude vs Wind Speed')
plt.savefig("../output_data/Fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
#skipping this is im already behind and turning it late

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
